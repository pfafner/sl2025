# %% [markdown]
# # **Aprendizaje Estadístico 2025** <font size=4 color='gray'>Alan Reyes-Figueroa</font>
# #### <font color='gray'>Análisis de componentes principales (PCA)</font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## 1. Leer datos

# %%
data = pd.read_csv('deport.csv', sep=',', header=0)
data.shape
# Out:
# (55, 9)

# %%
data.head()
# Out:
#     100m   200m   400m  800m  1500m    5km   10km  marath   country
# 0  10.39  20.81  46.84  1.81   3.70  14.04  29.36  137.72  argentin
# 1  10.31  20.06  44.84  1.74   3.57  13.28  27.66  128.30  australi
# 2  10.44  20.81  46.82  1.79   3.60  13.26  27.72  135.90   austria
# 3  10.34  20.68  45.04  1.73   3.60  13.22  27.45  129.95   belgium
# 4  10.28  20.58  45.91  1.80   3.75  14.68  30.55  146.62   bermuda

# %% [markdown]
# ## 2. Exploración de datos

# %%
# contar si hay datos faltantes

data.isna().sum()
# Out:
# 100m       0
# 200m       0
# 400m       0
# 800m       0
# 1500m      0
# 5km        0
# 10km       0
# marath     0
# country    0
# dtype: int64

# %%
# tipo de datos

data.dtypes
# Out:
# 100m       float64
# 200m       float64
# 400m       float64
# 800m       float64
# 1500m      float64
# 5km        float64
# 10km       float64
# marath     float64
# country     object
# dtype: object

# %%
# obtener estadísticas simples

data.describe()
# Out:
#             100m       200m       400m       800m      1500m        5km  \
# count  55.000000  55.000000  55.000000  55.000000  55.000000  55.000000
# mean   10.471091  20.940364  46.438727   1.793273   3.698182  13.845818
# std     0.351429   0.644647   1.457018   0.063685   0.155909   0.801160
# min     9.930000  19.720000  43.860000   1.700000   3.510000  13.010000
# 25%    10.270000  20.595000  45.560000   1.755000   3.600000  13.275000
# 50%    10.410000  20.810000  46.100000   1.790000   3.640000  13.500000
# 75%    10.590000  21.285000  47.300000   1.815000   3.770000  14.145000
# max    12.180000  23.200000  52.940000   2.020000   4.240000  16.700000
#
#             10km      marath
# count  55.000000   55.000000
# mean   28.989091  136.624000
# std     1.807732    9.227033
# min    27.380000  128.220000
# 25%    27.695000  130.705000
# 50%    28.190000  132.350000
# 75%    29.870000  139.300000
# max    35.380000  164.700000

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
# histogramas

plt.figure()
data.hist(figsize=(8,8))
plt.show()

# %%
# pairplots

plt.figure(figsize=(8,8))
sns.pairplot(data, diag_kind='kde')
plt.show()

# %% [markdown]
# ## 3. Descomposición SVD

# %%
# convertir los datos a un np.array

names = data.values[:,-1]

X = data.values[:,:-1].astype(np.float32)
X.shape
# Out:
# (55, 8)

# %%
type(X)
# Out:
# numpy.ndarray

# %%
print(X)
# Out:
# [[ 10.39  20.81  46.84   1.81   3.7   14.04  29.36 137.72]
#  [ 10.31  20.06  44.84   1.74   3.57  13.28  27.66 128.3 ]
#  [ 10.44  20.81  46.82   1.79   3.6   13.26  27.72 135.9 ]
#  [ 10.34  20.68  45.04   1.73   3.6   13.22  27.45 129.95]
#  [ 10.28  20.58  45.91   1.8    3.75  14.68  30.55 146.62]
#  [ 10.22  20.43  45.21   1.73   3.66  13.62  28.62 133.13]
#  [ 10.64  21.52  48.3    1.8    3.85  14.45  30.28 139.95]
#  [ 10.17  20.22  45.68   1.76   3.63  13.55  28.09 130.15]
#  [ 10.34  20.8   46.2    1.79   3.71  13.61  29.3  134.03]
#  [ 10.51  21.04  47.3    1.81   3.73  13.9   29.13 133.53]
#  [ 10.43  21.05  46.1    1.82   3.74  13.49  27.88 131.35]
#  [ 12.18  23.2   52.94   2.02   4.24  16.7   35.38 164.7 ]
#  [ 10.94  21.9   48.66   1.87   3.84  14.03  28.81 136.58]
#  [ 10.35  20.65  45.64   1.76   3.58  13.42  28.19 134.32]
#  [ 10.56  20.52  45.89   1.78   3.61  13.5   28.11 130.78]
#  [ 10.14  20.65  46.8    1.82   3.82  14.91  31.45 154.12]
#  [ 10.43  20.69  45.49   1.74   3.61  13.27  27.52 130.87]
#  [ 10.11  20.38  45.28   1.73   3.57  13.34  27.97 132.3 ]
#  [ 10.12  20.33  44.87   1.73   3.56  13.17  27.42 129.92]
#  [ 10.16  20.37  44.5    1.73   3.53  13.21  27.61 132.23]
#  [ 10.11  20.21  44.93   1.7    3.51  13.01  27.51 129.13]
#  [ 10.22  20.71  46.56   1.78   3.64  14.59  28.45 134.6 ]
#  [ 10.98  21.82  48.4    1.89   3.8   14.16  30.11 139.33]
#  [ 10.26  20.62  46.02   1.77   3.62  13.49  28.44 132.58]
#  [ 10.6   21.42  45.73   1.76   3.73  13.77  28.81 131.98]
#  [ 10.59  21.49  47.8    1.84   3.92  14.73  30.79 148.83]
#  [ 10.61  20.96  46.3    1.79   3.56  13.32  27.81 132.35]
#  [ 10.71  21.    47.8    1.77   3.72  13.66  28.93 137.55]
#  [ 10.01  19.72  45.26   1.73   3.6   13.23  27.52 131.08]
#  [ 10.34  20.81  45.86   1.79   3.64  13.41  27.72 128.63]
#  [ 10.46  20.66  44.92   1.73   3.55  13.1   27.38 129.75]
#  [ 10.34  20.89  46.9    1.79   3.77  13.96  29.23 136.25]
#  [ 10.91  21.94  47.3    1.85   3.77  14.13  29.67 130.87]
#  [ 10.35  20.77  47.4    1.82   3.67  13.64  29.08 141.27]
#  [ 10.4   20.92  46.3    1.82   3.8   14.64  31.01 154.1 ]
#  [ 11.19  22.45  47.7    1.88   3.83  15.06  31.77 152.23]
#  [ 10.42  21.3   46.1    1.8    3.65  13.46  27.95 129.2 ]
#  [ 10.52  20.95  45.1    1.74   3.62  13.36  27.61 129.02]
#  [ 10.51  20.88  46.1    1.74   3.54  13.21  27.7  128.98]
#  [ 10.55  21.16  46.71   1.76   3.62  13.34  27.69 131.48]
#  [ 10.96  21.78  47.9    1.9    4.01  14.72  31.36 148.22]
#  [ 10.78  21.64  46.24   1.81   3.83  14.74  30.64 145.27]
#  [ 10.16  20.24  45.36   1.76   3.6   13.29  27.89 131.58]
#  [ 10.53  21.17  46.7    1.79   3.62  13.13  27.38 128.65]
#  [ 10.41  20.98  45.87   1.76   3.64  13.25  27.67 132.5 ]
#  [ 10.38  21.28  47.4    1.88   3.89  15.11  31.32 157.77]
#  [ 10.42  20.77  45.98   1.76   3.55  13.31  27.73 131.57]
#  [ 10.25  20.61  45.63   1.77   3.61  13.29  27.94 130.63]
#  [ 10.37  20.46  45.78   1.78   3.55  13.22  27.91 131.2 ]
#  [ 10.59  21.29  46.8    1.79   3.77  14.07  30.07 139.27]
#  [ 10.39  21.09  47.91   1.83   3.84  15.23  32.56 149.9 ]
#  [ 10.71  21.43  47.6    1.79   3.67  13.56  28.58 131.5 ]
#  [  9.93  19.75  43.86   1.73   3.53  13.2   27.43 128.22]
#  [ 10.07  20.    44.6    1.75   3.59  13.2   27.53 130.55]
#  [ 10.82  21.86  49.     2.02   4.24  16.28  34.71 161.83]]

# %%
X.shape
# Out:
# (55, 8)

# %%
# centramos los datos

mu = X.mean(axis=0)

std = X.std(axis=0)

Xc = (X - mu) / std

# %%
mu
# Out:
# array([ 10.471092 ,  20.940363 ,  46.438732 ,   1.7932729,   3.6981816,
#         13.8458185,  28.989094 , 136.624    ], dtype=float32)

# %%
Xc.mean(axis=0)
# Out:
# array([-3.6434694e-06,  1.0295348e-06, -3.5004182e-06, -2.0894138e-06,
#         1.0447069e-06, -3.8580461e-07, -1.5388836e-06,  8.1929295e-07],
#       dtype=float32)

# %%
Xc.std(axis=0)
# Out:
# array([1.        , 1.        , 1.        , 0.9999999 , 1.        ,
#        1.        , 0.99999994, 0.99999994], dtype=float32)

# %%
# Otra forma de centrar los datos usando matrices de proyección

#n = X.shape[0]
#one = np.ones(n).reshape(-1,1)

#J = np.eye(n) - one@(one.T)/n       # matriz de proyección
#Xc = J@X                            # centramos los datos
#Xc = Xc / std                       # estandarización

# %%
# matriz de covarianzas
Cov = (Xc.T) @ Xc                 # @ = producto matricial

# %%
print(np.round(Cov, 2))
# Out:
# [[55.   50.75 46.26 41.58 38.51 34.07 34.79 28.6 ]
#  [50.75 55.   46.79 44.36 42.62 38.25 38.31 32.79]
#  [46.26 46.79 55.   47.86 45.94 42.82 43.3  38.77]
#  [41.58 44.36 47.86 55.   50.49 47.5  47.8  44.36]
#  [38.51 42.62 45.94 50.49 55.   51.05 51.41 47.61]
#  [34.07 38.25 42.82 47.5  51.05 55.   53.6  51.27]
#  [34.79 38.31 43.3  47.8  51.41 53.6  55.   51.87]
#  [28.6  32.79 38.77 44.36 47.61 51.27 51.87 55.  ]]

# %%
# Ahora vamos a usar la descomposición SVD de Xc

U, S, V = np.linalg.svd(Xc)

# %%
print(np.round(U, 2))
# Out:
# [[ 0.01 -0.05 -0.11 ... -0.2  -0.14  0.13]
#  [-0.13 -0.03  0.01 ... -0.2  -0.18  0.14]
#  [-0.04  0.07 -0.14 ...  0.14  0.04  0.01]
#  ...
#  [-0.18 -0.16 -0.01 ...  0.89 -0.07 -0.06]
#  [-0.14 -0.11 -0.07 ... -0.08  0.92 -0.06]
#  [ 0.38 -0.28 -0.24 ... -0.03 -0.04  0.57]]

# %%
U.shape
# Out:
# (55, 55)

# %%
print(S)
# Out:
# [19.084497   6.9475894  2.9601798  2.6120327  2.0960474  1.9334127
#   1.5978343  1.1149018]

# %%
print(np.round(V.T, 2))
# Out:
# [[ 0.32  0.57  0.33 -0.13  0.26  0.59  0.14  0.11]
#  [ 0.34  0.46  0.36  0.26 -0.15 -0.66 -0.11 -0.1 ]
#  [ 0.36  0.25 -0.56 -0.65 -0.22 -0.16 -0.   -0.  ]
#  [ 0.37  0.01 -0.53  0.48  0.54  0.01 -0.24 -0.04]
#  [ 0.37 -0.14 -0.15  0.4  -0.49  0.16  0.61  0.14]
#  [ 0.36 -0.31  0.19 -0.03 -0.25  0.14 -0.59  0.55]
#  [ 0.37 -0.31  0.18 -0.08 -0.13  0.22 -0.18 -0.8 ]
#  [ 0.34 -0.44  0.26 -0.3   0.5  -0.32  0.4   0.16]]

# %%
V.shape
# Out:
# (8, 8)

# %% [markdown]
# ### 1D

# %%
# proyección a 1D

X1 = Xc @ (V[:1,:].T)   #@np.diag(S[:1])
X1.shape
# Out:
# (55, 1)

# %%
plt.figure(figsize=(6,3))
#plt.plot(X1, np.zeros(X1.shape), 'bo')
plt.scatter(X1, np.zeros(X1.shape))
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.hist(X1, bins=17)
plt.show()

# %% [markdown]
# ### 2D

# %%
# proyección a 2D

X2 = Xc @ (V[:2,:].T)     #@np.diag(S[:2])
X2.shape
# Out:
# (55, 2)

# %%
plt.figure(figsize=(5,5))
plt.scatter(X2[:,0], X2[:,1])
plt.show()

# %%
fig = plt.figure(figsize=(5,5))
plt.scatter(X2[:,0], X2[:,1])
for i in range(0, X2.shape[0]):
    plt.annotate(names[i], (X2[i,0], X2[i,1]))
plt.show()

# %% [markdown]
# ### 3D

# %%
# proyección a 3D

X3 = Xc@(V[:3,:].T) #@np.diag(S[:3])
X3.shape
# Out:
# (55, 3)

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X3[:,0], X3[:,1], X3[:,2], marker='o')
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
plt.show()

# %% [markdown]
# ### Varianza explicada por cada componente

# %%
# Calculamos los autovalores de Cov(X) = X^TX (cuadrados de los valores singulares)
lambdas = S**2
print(lambdas)
# Out:
# [364.21805    48.268997    8.762665    6.822715    4.3934145   3.7380846
#    2.5530746   1.243006 ]

# %%
# Normalizamos los lambdas para que sumen 1
lambdas = lambdas / lambdas.sum()
print(lambdas)
# Out:
# [0.8277682  0.10970226 0.01991515 0.01550617 0.00998503 0.00849565
#  0.00580244 0.00282501]

# %%
lambdas.cumsum()
# Out:
# array([0.8277682 , 0.93747044, 0.9573856 , 0.97289175, 0.9828768 ,
#        0.9913724 , 0.99717486, 0.9999999 ], dtype=float32)

# %%
plt.figure()
plt.bar(np.arange(1,9), lambdas)
plt.plot(np.arange(1, 9), lambdas.cumsum(), 'r-')
plt.show()

# %% [markdown]
# Así la primera componente explica el 82.77% de la varianza de los datos, la segunda componente explica el 10.90% de la varianza de los datos.
#
# En suma, las primeras dos componentes explican el 93.74% de la variabilidad de los datos.

# %% [markdown]
# ## 4. PCA usando scikit-learn

# %%
from sklearn.decomposition import PCA

# %%
pcamodel = PCA(n_components=8)
pca2 = pcamodel.fit_transform(Xc)
pca2.shape
# Out:
# (55, 8)

# %%
pcamodel.explained_variance_
# Out:
# array([6.7447796 , 0.89386964, 0.1622717 , 0.12634654, 0.08135953,
#        0.06922377, 0.04727915, 0.02301861], dtype=float32)

# %%
pcamodel.explained_variance_ratio_
# Out:
# array([0.8277684 , 0.10970218, 0.01991516, 0.01550617, 0.00998503,
#        0.00849564, 0.00580244, 0.00282501], dtype=float32)

# %%
# Figura con el % de varianza explicada por cada componente
plt.figure(figsize=(5,5))
plt.bar(range(1,len(pcamodel.explained_variance_ )+1),pcamodel.explained_variance_ )
plt.ylabel('Explained variance')
plt.xlabel('Components')
plt.plot(range(1,len(pcamodel.explained_variance_ )+1),
         np.cumsum(pcamodel.explained_variance_),
         c='red',
         label="Cumulative Explained Variance")
plt.legend(loc='upper left')
plt.show()

# %%
def mybiplot(score, coeff, labels=None):
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    plt.scatter(xs * scalex,ys * scaley,s=5)
    for i in range(n):
        plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
        if labels is None:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'green', ha = 'center', va = 'center')
        else:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')
 
    plt.xlabel("PC{}".format(1))
    plt.ylabel("PC{}".format(2))
    plt.grid()

# %%
# Figura con my_biplot
plt.figure(figsize=(6,6))
mybiplot(pca2[:,0:2], np.transpose(pcamodel.components_[0:2, :]), list(data.columns[:-1]))
plt.show()

# %%
# Esta matriz da los componentes principales

components = pcamodel.components_.T
print(np.round(components, 2))
# Out:
# [[ 0.32 -0.57  0.33 -0.13 -0.26  0.59 -0.14  0.11]
#  [ 0.34 -0.46  0.36  0.26  0.15 -0.66  0.11 -0.1 ]
#  [ 0.36 -0.25 -0.56 -0.65  0.22 -0.16  0.   -0.  ]
#  [ 0.37 -0.01 -0.53  0.48 -0.54  0.01  0.24 -0.04]
#  [ 0.37  0.14 -0.15  0.4   0.49  0.16 -0.61  0.14]
#  [ 0.36  0.31  0.19 -0.03  0.25  0.14  0.59  0.55]
#  [ 0.37  0.31  0.18 -0.08  0.13  0.22  0.18 -0.8 ]
#  [ 0.34  0.44  0.26 -0.3  -0.5  -0.32 -0.4   0.16]]
